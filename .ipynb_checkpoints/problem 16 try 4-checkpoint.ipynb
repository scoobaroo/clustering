# %%
X = [
        [1.0,5.0],[1.25,5.35],[1.25,5.75],[1.5,6.25],[1.75,6.75],[2.0,6.5],[3.0,7.75],[3.5,8.25],[3.75,8.75],[3.95,9.1],
        [4.0,8.5],[2.5,7.25],[2.25,7.75],[2.0,6.5],[2.75,8.25],[4.5,8.9],[9.0,5.0],[8.75,5.85],[9.0,6.25],
        [8.0,7.0],[8.5,6.25],[8.5,6.75],[8.25,7.65],[7.0,8.25],[6.0,8.75],[5.5,8.25],[5.25,8.75],[4.9,8.75],
        [5.0,8.5],[7.5,7.75],[7.75,8.25],[6.75,8.0],[6.25,8.25],[4.5,8.9],[5.0,1.0],[1.25,4.65],[1.25,4.25],
        [1.5,3.75],[1.75,3.25],[2.0,3.5],[3.0,2.25],[3.5,1.75],[3.75,8.75],[3.95,0.9],[4.0,1.5],[2.5,2.75],
        [2.25,2.25],[2.0,3.5],[2.75,1.75],[4.5,1.1],[5.0,9.0],[8.75,5.15],[8.0,2.25],[8.25,3.0],[8.5,4.75],
        [8.5,4.25],[8.25,3.35],[7.0,1.75],[8.0,3.5],[6.0,1.25],[5.5,1.75],[5.25,1.25],[4.9,1.25],[5.0,1.5],
        [7.5,2.25],[7.75,2.75],[6.75,2.0],[6.25,1.75],[4.5,1.1],[3.0,4.5],[7.0,4.5],[5.0,3.0],[4.0,3.35],
        [6.0,3.35],[4.25,3.25],[5.75,3.25],[3.5,3.75],[6.5,3.75],[3.25,4.0],[6.75,4.0],[3.75,3.55],[6.25,3.55],
        [4.75,3.05],[5.25,3.05],[4.5,3.15],[5.5,3.15],[4.0,6.5],[4.0,6.75],[4.0,6.25],[3.75,6.5],[4.25,6.5],[4.25,6.75],
        [3.75,6.25],[6.0,6.5],[6.0,6.75],[6.0,6.25],[5.75,6.75],[5.75,6.25],[6.25,6.75],[6.25,6.25],[9.5,9.5],[2.5,9.5],[1.0,8.0]
    ]

# %%
newX = []
for item in X:
    point = Point(item[0],item[1])
    newX.append(point)
X = newX
X
# Out:
# [<__main__.Point at 0x10a085710>,
#  <__main__.Point at 0x10a085748>,
#  <__main__.Point at 0x10a085780>,
#  <__main__.Point at 0x10a0857b8>,
#  <__main__.Point at 0x10a0857f0>,
#  <__main__.Point at 0x10a085828>,
#  <__main__.Point at 0x10a085860>,
#  <__main__.Point at 0x10a085898>,
#  <__main__.Point at 0x10a0858d0>,
#  <__main__.Point at 0x10a085908>,
#  <__main__.Point at 0x10a085940>,
#  <__main__.Point at 0x10a085978>,
#  <__main__.Point at 0x10a0859b0>,
#  <__main__.Point at 0x10a0859e8>,
#  <__main__.Point at 0x10a085630>,
#  <__main__.Point at 0x10a0855c0>,
#  <__main__.Point at 0x10a085a90>,
#  <__main__.Point at 0x10a085ac8>,
#  <__main__.Point at 0x10a085b00>,
#  <__main__.Point at 0x10a085b38>,
#  <__main__.Point at 0x10a085b70>,
#  <__main__.Point at 0x10a085ba8>,
#  <__main__.Point at 0x10a085be0>,
#  <__main__.Point at 0x10a085c18>,
#  <__main__.Point at 0x10a085c50>,
#  <__main__.Point at 0x10a085c88>,
#  <__main__.Point at 0x10a085cc0>,
#  <__main__.Point at 0x10a085cf8>,
#  <__main__.Point at 0x10a085d30>,
#  <__main__.Point at 0x10a085d68>,
#  <__main__.Point at 0x10a085da0>,
#  <__main__.Point at 0x10a085dd8>,
#  <__main__.Point at 0x10a085a58>,
#  <__main__.Point at 0x10a085a20>,
#  <__main__.Point at 0x10a085e80>,
#  <__main__.Point at 0x10a085eb8>,
#  <__main__.Point at 0x10a085ef0>,
#  <__main__.Point at 0x10a085f28>,
#  <__main__.Point at 0x10a085f60>,
#  <__main__.Point at 0x10a085f98>,
#  <__main__.Point at 0x10a085fd0>,
#  <__main__.Point at 0x10a085e48>,
#  <__main__.Point at 0x10a085e10>,
#  <__main__.Point at 0x10a085048>,
#  <__main__.Point at 0x10a085080>,
#  <__main__.Point at 0x10a085470>,
#  <__main__.Point at 0x10a0850b8>,
#  <__main__.Point at 0x108842390>,
#  <__main__.Point at 0x108842cf8>,
#  <__main__.Point at 0x108842940>,
#  <__main__.Point at 0x108842978>,
#  <__main__.Point at 0x108842828>,
#  <__main__.Point at 0x10a09f048>,
#  <__main__.Point at 0x10a09f080>,
#  <__main__.Point at 0x10a09f0b8>,
#  <__main__.Point at 0x10a09f0f0>,
#  <__main__.Point at 0x10a09f128>,
#  <__main__.Point at 0x10a09f160>,
#  <__main__.Point at 0x10a09f198>,
#  <__main__.Point at 0x10a09f1d0>,
#  <__main__.Point at 0x10a09f208>,
#  <__main__.Point at 0x10a09f240>,
#  <__main__.Point at 0x10a09f278>,
#  <__main__.Point at 0x10a09f2b0>,
#  <__main__.Point at 0x10a09f2e8>,
#  <__main__.Point at 0x10a09f320>,
#  <__main__.Point at 0x10a09f358>,
#  <__main__.Point at 0x10a09f390>,
#  <__main__.Point at 0x10a09f3c8>,
#  <__main__.Point at 0x10a09f400>,
#  <__main__.Point at 0x10a09f438>,
#  <__main__.Point at 0x10a09f470>,
#  <__main__.Point at 0x10a09f4a8>,
#  <__main__.Point at 0x10a09f4e0>,
#  <__main__.Point at 0x10a09f518>,
#  <__main__.Point at 0x10a09f550>,
#  <__main__.Point at 0x10a09f588>,
#  <__main__.Point at 0x10a09f5c0>,
#  <__main__.Point at 0x10a09f5f8>,
#  <__main__.Point at 0x10a09f630>,
#  <__main__.Point at 0x10a09f668>,
#  <__main__.Point at 0x10a09f6a0>,
#  <__main__.Point at 0x10a09f6d8>,
#  <__main__.Point at 0x10a09f710>,
#  <__main__.Point at 0x10a09f748>,
#  <__main__.Point at 0x10a09f780>,
#  <__main__.Point at 0x10a09f7b8>,
#  <__main__.Point at 0x10a09f7f0>,
#  <__main__.Point at 0x10a09f828>,
#  <__main__.Point at 0x10a09f860>,
#  <__main__.Point at 0x10a09f898>,
#  <__main__.Point at 0x10a09f8d0>,
#  <__main__.Point at 0x10a09f908>,
#  <__main__.Point at 0x10a09f940>,
#  <__main__.Point at 0x10a09f978>,
#  <__main__.Point at 0x10a09f9b0>,
#  <__main__.Point at 0x10a09f9e8>,
#  <__main__.Point at 0x10a09fa20>,
#  <__main__.Point at 0x10a09fa58>,
#  <__main__.Point at 0x10a09fa90>,
#  <__main__.Point at 0x10a09fac8>,
#  <__main__.Point at 0x10a09fb00>,
#  <__main__.Point at 0x10a09fb38>]

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
from numpy import sqrt
def regionQuery(Point, epsilon, X):
    neighbourPts = []
    for point in X:
        cp = Point.toArray()
        p = point.toArray()
        if sqrt((cp[0] - p[0])**2 + (cp[1] - p[1])**2)<epsilon:
            neighbourPts.append(point)
    return neighbourPts

# %%
regionQuery(X[40], 2, X)
# Out:
# [<__main__.Point at 0x10a085f60>,
#  <__main__.Point at 0x10a085f98>,
#  <__main__.Point at 0x10a085fd0>,
#  <__main__.Point at 0x10a085e48>,
#  <__main__.Point at 0x10a085048>,
#  <__main__.Point at 0x10a085080>,
#  <__main__.Point at 0x10a085470>,
#  <__main__.Point at 0x10a0850b8>,
#  <__main__.Point at 0x108842390>,
#  <__main__.Point at 0x108842cf8>,
#  <__main__.Point at 0x108842940>,
#  <__main__.Point at 0x10a09f3c8>,
#  <__main__.Point at 0x10a09f4a8>,
#  <__main__.Point at 0x10a09f518>,
#  <__main__.Point at 0x10a09f588>,
#  <__main__.Point at 0x10a09f5f8>,
#  <__main__.Point at 0x10a09f668>,
#  <__main__.Point at 0x10a09f6d8>,
#  <__main__.Point at 0x10a09f748>]

# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def toArray(self):
        return [self.x,self.y]
    def set_core_point(self):
        self.core_point=True
    def get_core_point(self):
        return self.core_point
    def set_reachable_point(self):
        self.reachable_point=True
    def get_reachable_point(self):
        return self.reachable_point

class Cluster:
    points = []
    clusterCount = 0
    def __init__(self,cn):
        self.cn = cn
        self.points = []
        self.clusterCount +=1
        self.core_point = False
        self.reachable_point = False
    def get_cluster(self):
        return "cluster"+self.cn
    def add_point(self,pt):
        self.points.append(pt)
    def get_point_count(self):
        return len(points)
    def get_points(self):
        return self.points
    def has(self,point):
        return point in self.points
    def __str__(self):
        return "Cluster %s: %d points" % (self.cn, len(self.points))
point1 = Point(1,2)
point2 = Point(3,4)
c = Cluster("1")
c.add_point(point1)
c.add_point(point2)
for p in c.get_points():
    print(p.toArray())
# Out:
# [1, 2]
# [3, 4]

# %%
def expandCluster(P, neighbourPoints, allClusters, cluster, epsilon, m, X, visited, available):
    cluster.add_point(P)
    for point in neighbourPoints:
        if point not in visited:
            visited.append(point)
            neighbourPts_2 = regionQuery(point, epsilon, X)
            if len(neighbourPts_2) >= m:
                for p in neighbourPts_2:
                    cluster.add_point(p)
                    visited.append(p)
                neighbourPoints+=neighbourPts_2
        if point not in (c for c in allClusters):
            cluster.add_point(P)

# %%
def DBSCAN(X, epsilon, m):
    outliers = []
    visited = []
    reachablePoints = []
    allClusters = []
    available = X.copy()
    cn = -1
    for point in available:
        if point not in visited:
            visited.append(point)
            neighbourPoints = regionQuery(point, epsilon, X)
        if len(neighbourPoints) < m:
            outliers.append(point)
        else:
            cn+=1
            cluster = Cluster(cn)
            allClusters.append(cluster)
            expandCluster(point, neighbourPoints, allClusters, cluster, epsilon, m, X, visited, available)
    print("Number of clusters: ", len(allClusters))
    for cluster in allClusters:
        cluster.__str__()
    cmap = plt.cm.get_cmap('gist_ncar', len(allClusters))
    print ("number of outliers:", len(outliers))
    for i in range(len(allClusters)):
        print(allClusters[i])
        cluster = allClusters[i]
        clusterPoints = cluster.get_points()
        for point in clusterPoints:
            p = point.toArray()
            plt.scatter(p[0],p[1],color = cmap(i))
    plt.show()

# %%
DBSCAN(newX,0.6,3)
# Out:
# Number of clusters:  63
# number of outliers: 40
# Cluster 0: 16 points
# Cluster 1: 10 points
# Cluster 2: 10 points
# Cluster 3: 14 points
# Cluster 4: 10 points
# Cluster 5: 10 points
# Cluster 6: 15 points
# Cluster 7: 10 points
# Cluster 8: 10 points
# Cluster 9: 10 points
# Cluster 10: 18 points
# Cluster 11: 10 points
# Cluster 12: 10 points
# Cluster 13: 7 points
# Cluster 14: 4 points
# Cluster 15: 4 points
# Cluster 16: 4 points
# Cluster 17: 4 points
# Cluster 18: 4 points
# Cluster 19: 10 points
# Cluster 20: 7 points
# Cluster 21: 7 points
# Cluster 22: 27 points
# Cluster 23: 17 points
# Cluster 24: 17 points
# Cluster 25: 14 points
# Cluster 26: 10 points
# Cluster 27: 10 points
# Cluster 28: 10 points
# Cluster 29: 11 points
# Cluster 30: 8 points
# Cluster 31: 10 points
# Cluster 32: 7 points
# Cluster 33: 7 points
# Cluster 34: 26 points
# Cluster 35: 13 points
# Cluster 36: 9 points
# Cluster 37: 9 points
# Cluster 38: 9 points
# Cluster 39: 9 points
# Cluster 40: 18 points
# Cluster 41: 4 points
# Cluster 42: 4 points
# Cluster 43: 4 points
# Cluster 44: 4 points
# Cluster 45: 4 points
# Cluster 46: 4 points
# Cluster 47: 4 points
# Cluster 48: 4 points
# Cluster 49: 22 points
# Cluster 50: 15 points
# Cluster 51: 15 points
# Cluster 52: 15 points
# Cluster 53: 15 points
# Cluster 54: 15 points
# Cluster 55: 15 points
# Cluster 56: 22 points
# Cluster 57: 15 points
# Cluster 58: 15 points
# Cluster 59: 15 points
# Cluster 60: 15 points
# Cluster 61: 15 points
# Cluster 62: 15 points

# %%
def scan(data,m,epsilon):
    cn = 0
    visited = []
    available = data.copy()
    outliers = []
    allClusters = []
    for point1 in available:
        visited.append(point1)
        count = 1
        neighborPoints = regionQuery(point1, epsilon, data)
        if (len(neighborPoints)+1) >=m:
            point1.set_core_point()
            if point1 not in (c for c in allClusters):
                cn+=1
                cluster = Cluster(cn)
                cluster.add_point(point1)
                for p in neighborPoints:
                    if p not in (c for c in allClusters):
                        cluster.add_point(p)
                    points2 = regionQuery(p,epsilon,data)
                    if (len(points2)+1) > m:
                        p.set_core_point()
                for p in neighborPoints:
                    neighborPoints2 = regionQuery(p, epsilon, data)
                    for p2 in neighborPoints2:
                        p3 = p.toArray()
                        p4 = p2.toArray()
                        if distance(p3,p4) < epsilon:
                            cluster.add_point(p2)
            allClusters.append(cluster)
            available.remove(point1)
        elif (len(neighborPoints)+1) < m:
            point1.set_reachable_point()
            if p not in (c for c in allClusters):
                cluster.add_point(p)
            available.remove(point1)
    print("Number of clusters: ", len(allClusters))
    for cluster in allClusters:
        print(cluster.__str__())    
    cmap = plt.cm.get_cmap('gist_ncar', len(allClusters))
    print ("number of outliers:", len(outliers))
    for i in range(len(allClusters)):
        print(allClusters[i])
        cluster = allClusters[i]
        clusterPoints = cluster.get_points()
        for point in clusterPoints:
            p = point.toArray()
            plt.scatter(p[0],p[1],color = cmap(i))
    plt.show()

# %%
from numpy import sqrt
def regionQuery(Point, epsilon, X):
    neighbourPts = []
    for point in X:
        p1 = Point.toArray()
        p2 = point.toArray()
        if distance(p1,p2) <epsilon:
            neighbourPts.append(point)
    return neighbourPts

def distance(point1,point2):
    return sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)

# %%
scan(X,3,0.6)
# Out:
# Number of clusters:  49
# Cluster 1: 13 points
# Cluster 2: 15 points
# Cluster 3: 22 points
# Cluster 4: 7 points
# Cluster 5: 29 points
# Cluster 6: 23 points
# Cluster 7: 7 points
# Cluster 8: 7 points
# Cluster 9: 14 points
# Cluster 10: 14 points
# Cluster 11: 19 points
# Cluster 12: 8 points
# Cluster 13: 31 points
# Cluster 14: 31 points
# Cluster 15: 7 points
# Cluster 16: 12 points
# Cluster 17: 39 points
# Cluster 18: 15 points
# Cluster 19: 22 points
# Cluster 20: 7 points
# Cluster 21: 29 points
# Cluster 22: 7 points
# Cluster 23: 7 points
# Cluster 24: 7 points
# Cluster 25: 39 points
# Cluster 26: 14 points
# Cluster 27: 17 points
# Cluster 28: 14 points
# Cluster 29: 14 points
# Cluster 30: 17 points
# Cluster 31: 39 points
# Cluster 32: 14 points
# Cluster 33: 12 points
# Cluster 34: 31 points
# Cluster 35: 8 points
# Cluster 36: 23 points
# Cluster 37: 29 points
# Cluster 38: 14 points
# Cluster 39: 12 points
# Cluster 40: 21 points
# Cluster 41: 31 points
# Cluster 42: 30 points
# Cluster 43: 55 points
# Cluster 44: 55 points
# Cluster 45: 55 points
# Cluster 46: 48 points
# Cluster 47: 53 points
# Cluster 48: 46 points
# Cluster 49: 48 points
# number of outliers: 0
# Cluster 1: 13 points
# Cluster 2: 15 points
# Cluster 3: 22 points
# Cluster 4: 7 points
# Cluster 5: 29 points
# Cluster 6: 23 points
# Cluster 7: 7 points
# Cluster 8: 7 points
# Cluster 9: 14 points
# Cluster 10: 14 points
# Cluster 11: 19 points
# Cluster 12: 8 points
# Cluster 13: 31 points
# Cluster 14: 31 points
# Cluster 15: 7 points
# Cluster 16: 12 points
# Cluster 17: 39 points
# Cluster 18: 15 points
# Cluster 19: 22 points
# Cluster 20: 7 points
# Cluster 21: 29 points
# Cluster 22: 7 points
# Cluster 23: 7 points
# Cluster 24: 7 points
# Cluster 25: 39 points
# Cluster 26: 14 points
# Cluster 27: 17 points
# Cluster 28: 14 points
# Cluster 29: 14 points
# Cluster 30: 17 points
# Cluster 31: 39 points
# Cluster 32: 14 points
# Cluster 33: 12 points
# Cluster 34: 31 points
# Cluster 35: 8 points
# Cluster 36: 23 points
# Cluster 37: 29 points
# Cluster 38: 14 points
# Cluster 39: 12 points
# Cluster 40: 21 points
# Cluster 41: 31 points
# Cluster 42: 30 points
# Cluster 43: 55 points
# Cluster 44: 55 points
# Cluster 45: 55 points
# Cluster 46: 48 points
# Cluster 47: 53 points
# Cluster 48: 46 points
# Cluster 49: 48 points
